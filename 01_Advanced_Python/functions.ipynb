# %%
# add function
def add(a,b):
    return a+b

add(3,4)
# Out:
# 7

# %%
# subtract function
def subtract(a,b):
    return a-b 
subtract(5,9)
# Out:
# -4

# %%
# multiply function
def multiply(a,b):
    return a*b
multiply(4,3)
# Out:
# 12
